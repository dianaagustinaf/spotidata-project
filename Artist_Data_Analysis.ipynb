# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
# Read songs.csv file
artist_data = pd.read_csv("artist_data.csv")

# %%
artist_data
# Out:
#      Position           Artist       Genre    Lead Streams Featured streams  \
# 0           1            Drake     Hip-Hop  45,930,207,058   17,624,649,510
# 1           2       Ed Sheeran         Pop  35,009,165,977    2,537,534,050
# 2           3        Bad Bunny  Latin Trap  33,838,992,346    4,440,723,306
# 3           4       The Weeknd    R&B/Soul  30,759,273,612    3,858,847,246
# 4           5    Ariana Grande         Pop  30,199,885,343    1,934,573,510
# ..        ...              ...         ...             ...              ...
# 995       996         Upchurch         NaN   1,233,720,207      136,998,161
# 996       997  Hungria Hip Hop         NaN   1,233,176,813       69,096,039
# 997       998          Chicago         NaN   1,232,497,152                5
# 998       999            Riton         NaN   1,231,385,490       21,351,886
# 999      1000          BIGBANG         NaN   1,231,303,296                1
#
#      Tracks  1b  100m  10m   1m    Update % Songs Streamed 1Million Times  \
# 0     248.0   6   117  241  244  11.04.22                             98%
# 1     222.0  10    59  166  200  11.04.22                             90%
# 2     141.0   3    89  134  140  11.04.22                             99%
# 3     178.0   6    69  143  161  11.04.22                             90%
# 4     181.0   5    69  126  175  11.04.22                             97%
# ..      ...  ..   ...  ...  ...       ...                             ...
# 995   225.0   0     0   29  177  03.03.22                             79%
# 996    63.0   0     1   37   59  04.12.21                             94%
# 997   725.0   0     4   11   56  22.03.22                              8%
# 998   118.0   0     3    8   24  01.03.22                             20%
# 999   381.0   0     2   23   60  09.04.22                             16%
#
#     % Songs Streamed 10Million Times % Songs Streamed 100Million Times  \
# 0                                97%                               47%
# 1                                75%                               27%
# 2                                95%                               63%
# 3                                80%                               39%
# 4                                70%                               38%
# ..                               ...                               ...
# 995                              13%                                0%
# 996                              59%                                2%
# 997                               2%                                1%
# 998                               7%                                3%
# 999                               6%                                1%
#
#     % Songs Streamed 1Billion Times
# 0                                2%
# 1                                5%
# 2                                2%
# 3                                3%
# 4                                3%
# ..                              ...
# 995                              0%
# 996                              0%
# 997                              0%
# 998                              0%
# 999                              0%
#
# [1000 rows x 15 columns]

# %%
# print colummns list 
print(artist_data.columns)
# Out:
# Index(['Position', 'Artist', 'Genre', 'Lead Streams', 'Featured streams',
#        'Tracks', '1b', '100m', '10m', '1m', 'Update',
#        '% Songs Streamed 1Million Times', '% Songs Streamed 10Million Times',
#        '% Songs Streamed 100Million Times', '% Songs Streamed 1Billion Times'],
#       dtype='object')

# %%
# convert to dataframe
artist_df = pd.DataFrame(artist_data)

# %%
# Show df
artist_df
# Out:
#      Position           Artist       Genre    Lead Streams Featured streams  \
# 0           1            Drake     Hip-Hop  45,930,207,058   17,624,649,510
# 1           2       Ed Sheeran         Pop  35,009,165,977    2,537,534,050
# 2           3        Bad Bunny  Latin Trap  33,838,992,346    4,440,723,306
# 3           4       The Weeknd    R&B/Soul  30,759,273,612    3,858,847,246
# 4           5    Ariana Grande         Pop  30,199,885,343    1,934,573,510
# ..        ...              ...         ...             ...              ...
# 995       996         Upchurch         NaN   1,233,720,207      136,998,161
# 996       997  Hungria Hip Hop         NaN   1,233,176,813       69,096,039
# 997       998          Chicago         NaN   1,232,497,152                5
# 998       999            Riton         NaN   1,231,385,490       21,351,886
# 999      1000          BIGBANG         NaN   1,231,303,296                1
#
#      Tracks  1b  100m  10m   1m    Update % Songs Streamed 1Million Times  \
# 0     248.0   6   117  241  244  11.04.22                             98%
# 1     222.0  10    59  166  200  11.04.22                             90%
# 2     141.0   3    89  134  140  11.04.22                             99%
# 3     178.0   6    69  143  161  11.04.22                             90%
# 4     181.0   5    69  126  175  11.04.22                             97%
# ..      ...  ..   ...  ...  ...       ...                             ...
# 995   225.0   0     0   29  177  03.03.22                             79%
# 996    63.0   0     1   37   59  04.12.21                             94%
# 997   725.0   0     4   11   56  22.03.22                              8%
# 998   118.0   0     3    8   24  01.03.22                             20%
# 999   381.0   0     2   23   60  09.04.22                             16%
#
#     % Songs Streamed 10Million Times % Songs Streamed 100Million Times  \
# 0                                97%                               47%
# 1                                75%                               27%
# 2                                95%                               63%
# 3                                80%                               39%
# 4                                70%                               38%
# ..                               ...                               ...
# 995                              13%                                0%
# 996                              59%                                2%
# 997                               2%                                1%
# 998                               7%                                3%
# 999                               6%                                1%
#
#     % Songs Streamed 1Billion Times
# 0                                2%
# 1                                5%
# 2                                2%
# 3                                3%
# 4                                3%
# ..                              ...
# 995                              0%
# 996                              0%
# 997                              0%
# 998                              0%
# 999                              0%
#
# [1000 rows x 15 columns]

# %%
artist_df.describe()
# Out:
#           Position       Tracks           1b         100m         10m  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean    500.500000   185.574921     0.289000     8.133000    44.56600
# std     288.819436   164.501797     0.917781    10.380417    30.87528
# min       1.000000     1.028000     0.000000     0.000000     0.00000
# 25%     250.750000    81.000000     0.000000     3.000000    24.00000
# 50%     500.500000   138.000000     0.000000     5.000000    36.00000
# 75%     750.250000   233.000000     0.000000     9.000000    56.00000
# max    1000.000000   979.000000    10.000000   117.000000   246.00000
#
#                 1m
# count  1000.000000
# mean    115.270000
# std      72.643087
# min      10.000000
# 25%      66.750000
# 50%      97.000000
# 75%     145.000000
# max     606.000000

# %%
# Mean No. of tracks = 186, 
# SD = 164.50, 
# Max No.of tracks = 979,
# Min No. of tracks = 1.03    *** need to clean data as cannot have floats****
# Median 1st quartile = 81,
# Median 2nd quartile = 138,
# Median 3rd quartile = 233

# %% [markdown]
# ## Data cleanup remove rows with errors - Tracks as floats convert to integers

# %%
s = artist_df['Tracks']
artist_df['Tracks'] = artist_df['Tracks'].astype(int)

artist_df = artist_df[artist_df['Tracks'] == s]
print(artist_df)
# Out:
#      Position           Artist       Genre    Lead Streams Featured streams  \
# 0           1            Drake     Hip-Hop  45,930,207,058   17,624,649,510
# 1           2       Ed Sheeran         Pop  35,009,165,977    2,537,534,050
# 2           3        Bad Bunny  Latin Trap  33,838,992,346    4,440,723,306
# 3           4       The Weeknd    R&B/Soul  30,759,273,612    3,858,847,246
# 4           5    Ariana Grande         Pop  30,199,885,343    1,934,573,510
# ..        ...              ...         ...             ...              ...
# 995       996         Upchurch         NaN   1,233,720,207      136,998,161
# 996       997  Hungria Hip Hop         NaN   1,233,176,813       69,096,039
# 997       998          Chicago         NaN   1,232,497,152                5
# 998       999            Riton         NaN   1,231,385,490       21,351,886
# 999      1000          BIGBANG         NaN   1,231,303,296                1
#
#      Tracks  1b  100m  10m   1m    Update % Songs Streamed 1Million Times  \
# 0       248   6   117  241  244  11.04.22                             98%
# 1       222  10    59  166  200  11.04.22                             90%
# 2       141   3    89  134  140  11.04.22                             99%
# 3       178   6    69  143  161  11.04.22                             90%
# 4       181   5    69  126  175  11.04.22                             97%
# ..      ...  ..   ...  ...  ...       ...                             ...
# 995     225   0     0   29  177  03.03.22                             79%
# 996      63   0     1   37   59  04.12.21                             94%
# 997     725   0     4   11   56  22.03.22                              8%
# 998     118   0     3    8   24  01.03.22                             20%
# 999     381   0     2   23   60  09.04.22                             16%
#
#     % Songs Streamed 10Million Times % Songs Streamed 100Million Times  \
# 0                                97%                               47%
# 1                                75%                               27%
# 2                                95%                               63%
# 3                                80%                               39%
# 4                                70%                               38%
# ..                               ...                               ...
# 995                              13%                                0%
# 996                              59%                                2%
# 997                               2%                                1%
# 998                               7%                                3%
# 999                               6%                                1%
#
#     % Songs Streamed 1Billion Times
# 0                                2%
# 1                                5%
# 2                                2%
# 3                                3%
# 4                                3%
# ..                              ...
# 995                              0%
# 996                              0%
# 997                              0%
# 998                              0%
# 999                              0%
#
# [972 rows x 15 columns]

# %%
artist_df.head()
# Out:
#    Position         Artist       Genre    Lead Streams Featured streams  \
# 0         1          Drake     Hip-Hop  45,930,207,058   17,624,649,510
# 1         2     Ed Sheeran         Pop  35,009,165,977    2,537,534,050
# 2         3      Bad Bunny  Latin Trap  33,838,992,346    4,440,723,306
# 3         4     The Weeknd    R&B/Soul  30,759,273,612    3,858,847,246
# 4         5  Ariana Grande         Pop  30,199,885,343    1,934,573,510
#
#    Tracks  1b  100m  10m   1m    Update % Songs Streamed 1Million Times  \
# 0     248   6   117  241  244  11.04.22                             98%
# 1     222  10    59  166  200  11.04.22                             90%
# 2     141   3    89  134  140  11.04.22                             99%
# 3     178   6    69  143  161  11.04.22                             90%
# 4     181   5    69  126  175  11.04.22                             97%
#
#   % Songs Streamed 10Million Times % Songs Streamed 100Million Times  \
# 0                              97%                               47%
# 1                              75%                               27%
# 2                              95%                               63%
# 3                              80%                               39%
# 4                              70%                               38%
#
#   % Songs Streamed 1Billion Times
# 0                              2%
# 1                              5%
# 2                              2%
# 3                              3%
# 4                              3%

# %%
artist_df.describe()
# Out:
#           Position      Tracks          1b        100m         10m          1m
# count   972.000000  972.000000  972.000000  972.000000  972.000000  972.000000
# mean    498.747942  190.829218    0.296296    8.254115   44.858025  111.655350
# std     289.075392  163.871492    0.929362   10.479652   30.977125   66.762098
# min       1.000000   11.000000    0.000000    0.000000    2.000000   10.000000
# 25%     248.750000   84.750000    0.000000    3.000000   24.000000   66.000000
# 50%     499.500000  139.000000    0.000000    5.000000   37.000000   96.000000
# 75%     748.250000  235.000000    0.000000   10.000000   56.000000  141.000000
# max    1000.000000  979.000000   10.000000  117.000000  246.000000  606.000000

# %%
# Mean No. of tracks = 191, 
# SD = 164.87, 
# Max No.of tracks = 979,
# Min No. of tracks = 11    
# Median 1st quartile = 85,
# Median 2nd quartile = 139,
# Median 3rd quartile = 235

# %% [markdown]
# ## Remove % symbol to clean up data frame for analysis later

# %%
# Remove % symbol to clean up data frame for analysis later

cols_to_check = ['% Songs Streamed 1Million Times', '% Songs Streamed 10Million Times', '% Songs Streamed 100Million Times', '% Songs Streamed 1Billion Times']
print(artist_df[cols_to_check])
 
artist_df[cols_to_check] = artist_df[cols_to_check].replace({'%': ''}, regex=True)
print(artist_df)
# Out:
#     % Songs Streamed 1Million Times % Songs Streamed 10Million Times  \
# 0                               98%                              97%
# 1                               90%                              75%
# 2                               99%                              95%
# 3                               90%                              80%
# 4                               97%                              70%
# ..                              ...                              ...
# 995                             79%                              13%
# 996                             94%                              59%
# 997                              8%                               2%
# 998                             20%                               7%
# 999                             16%                               6%
#
#     % Songs Streamed 100Million Times % Songs Streamed 1Billion Times
# 0                                 47%                              2%
# 1                                 27%                              5%
# 2                                 63%                              2%
# 3                                 39%                              3%
# 4                                 38%                              3%
# ..                                ...                             ...
# 995                                0%                              0%
# 996                                2%                              0%
# 997                                1%                              0%
# 998                                3%                              0%
# 999                                1%                              0%
#
# [972 rows x 4 columns]
#      Position           Artist       Genre    Lead Streams Featured streams  \
# 0           1            Drake     Hip-Hop  45,930,207,058   17,624,649,510
# 1           2       Ed Sheeran         Pop  35,009,165,977    2,537,534,050
# 2           3        Bad Bunny  Latin Trap  33,838,992,346    4,440,723,306
# 3           4       The Weeknd    R&B/Soul  30,759,273,612    3,858,847,246
# 4           5    Ariana Grande         Pop  30,199,885,343    1,934,573,510
# ..        ...              ...         ...             ...              ...
# 995       996         Upchurch         NaN   1,233,720,207      136,998,161
# 996       997  Hungria Hip Hop         NaN   1,233,176,813       69,096,039
# 997       998          Chicago         NaN   1,232,497,152                5
# 998       999            Riton         NaN   1,231,385,490       21,351,886
# 999      1000          BIGBANG         NaN   1,231,303,296                1
#
#      Tracks  1b  100m  10m   1m    Update % Songs Streamed 1Million Times  \
# 0       248   6   117  241  244  11.04.22                              98
# 1       222  10    59  166  200  11.04.22                              90
# 2       141   3    89  134  140  11.04.22                              99
# 3       178   6    69  143  161  11.04.22                              90
# 4       181   5    69  126  175  11.04.22                              97
# ..      ...  ..   ...  ...  ...       ...                             ...
# 995     225   0     0   29  177  03.03.22                              79
# 996      63   0     1   37   59  04.12.21                              94
# 997     725   0     4   11   56  22.03.22                               8
# 998     118   0     3    8   24  01.03.22                              20
# 999     381   0     2   23   60  09.04.22                              16
#
#     % Songs Streamed 10Million Times % Songs Streamed 100Million Times  \
# 0                                 97                                47
# 1                                 75                                27
# 2                                 95                                63
# 3                                 80                                39
# 4                                 70                                38
# ..                               ...                               ...
# 995                               13                                 0
# 996                               59                                 2
# 997                                2                                 1
# 998                                7                                 3
# 999                                6                                 1
#
#     % Songs Streamed 1Billion Times
# 0                                 2
# 1                                 5
# 2                                 2
# 3                                 3
# 4                                 3
# ..                              ...
# 995                               0
# 996                               0
# 997                               0
# 998                               0
# 999                               0
#
# [972 rows x 15 columns]
# C:\Users\VAIO\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# Check if % has been removed
artist_df.head()
# Out:
#    Position         Artist       Genre    Lead Streams Featured streams  \
# 0         1          Drake     Hip-Hop  45,930,207,058   17,624,649,510
# 1         2     Ed Sheeran         Pop  35,009,165,977    2,537,534,050
# 2         3      Bad Bunny  Latin Trap  33,838,992,346    4,440,723,306
# 3         4     The Weeknd    R&B/Soul  30,759,273,612    3,858,847,246
# 4         5  Ariana Grande         Pop  30,199,885,343    1,934,573,510
#
#    Tracks  1b  100m  10m   1m    Update % Songs Streamed 1Million Times  \
# 0     248   6   117  241  244  11.04.22                              98
# 1     222  10    59  166  200  11.04.22                              90
# 2     141   3    89  134  140  11.04.22                              99
# 3     178   6    69  143  161  11.04.22                              90
# 4     181   5    69  126  175  11.04.22                              97
#
#   % Songs Streamed 10Million Times % Songs Streamed 100Million Times  \
# 0                               97                                47
# 1                               75                                27
# 2                               95                                63
# 3                               80                                39
# 4                               70                                38
#
#   % Songs Streamed 1Billion Times
# 0                               2
# 1                               5
# 2                               2
# 3                               3
# 4                               3

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 972 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Position                           972 non-null    int64
#  1   Artist                             972 non-null    object
#  2   Genre                              99 non-null     object
#  3   Lead Streams                       972 non-null    object
#  4   Featured streams                   972 non-null    object
#  5   Tracks                             972 non-null    int32
#  6   1b                                 972 non-null    int64
#  7   100m                               972 non-null    int64
#  8   10m                                972 non-null    int64
#  9   1m                                 972 non-null    int64
#  10  Update                             972 non-null    object
#  11  % Songs Streamed 1Million Times    972 non-null    object
#  12  % Songs Streamed 10Million Times   972 non-null    object
#  13  % Songs Streamed 100Million Times  972 non-null    object
#  14  % Songs Streamed 1Billion Times    972 non-null    object
# dtypes: int32(1), int64(5), object(9)
# memory usage: 117.7+ KB

# %%
# Remove non essential rows - 'Featured Streams' and 'update' 
artist_df_cleaned = artist_df.drop(columns=["Featured streams","Update", "% Songs Streamed 1Million Times", "1m"])
artist_df_cleaned.head()
# Out:
#    Position         Artist       Genre    Lead Streams  Tracks  1b  100m  10m  \
# 0         1          Drake     Hip-Hop  45,930,207,058     248   6   117  241
# 1         2     Ed Sheeran         Pop  35,009,165,977     222  10    59  166
# 2         3      Bad Bunny  Latin Trap  33,838,992,346     141   3    89  134
# 3         4     The Weeknd    R&B/Soul  30,759,273,612     178   6    69  143
# 4         5  Ariana Grande         Pop  30,199,885,343     181   5    69  126
#
#   % Songs Streamed 10Million Times % Songs Streamed 100Million Times  \
# 0                               97                                47
# 1                               75                                27
# 2                               95                                63
# 3                               80                                39
# 4                               70                                38
#
#   % Songs Streamed 1Billion Times
# 0                               2
# 1                               5
# 2                               2
# 3                               3
# 4                               3

# %% [markdown]
# ## Start of data analysis

# %% [markdown]
# # How many songs did they make on average?

# %%
# Total number of tracks from 1000 artists and average number of tracks per artist.

Total_Tracks = artist_df_cleaned["Tracks"].sum()
artist_count = artist_df_cleaned["Tracks"].count()
Total_number_of_Artists = str(artist_count)
#print(Total_number_of_Artists)

print(f"The Total number of Tracks in the top 1000 artist playlist are: {Total_Tracks}")
print(f"The Average number of Tracks per artist: { round(Total_Tracks / artist_count) }")
# Out:
# The Total number of Tracks in the top 1000 artist playlist are: 185486
# The Average number of Tracks per artist: 191

# %%
# rename columns

artist_df_cleaned.rename(columns = {
    '1b':'1 Billion', 
    '100m':'100 Million', 
    '10m':'10 Million',
})
# Out:
#      Position           Artist       Genre    Lead Streams  Tracks  1 Billion  \
# 0           1            Drake     Hip-Hop  45,930,207,058     248          6
# 1           2       Ed Sheeran         Pop  35,009,165,977     222         10
# 2           3        Bad Bunny  Latin Trap  33,838,992,346     141          3
# 3           4       The Weeknd    R&B/Soul  30,759,273,612     178          6
# 4           5    Ariana Grande         Pop  30,199,885,343     181          5
# ..        ...              ...         ...             ...     ...        ...
# 995       996         Upchurch         NaN   1,233,720,207     225          0
# 996       997  Hungria Hip Hop         NaN   1,233,176,813      63          0
# 997       998          Chicago         NaN   1,232,497,152     725          0
# 998       999            Riton         NaN   1,231,385,490     118          0
# 999      1000          BIGBANG         NaN   1,231,303,296     381          0
#
#      100 Million  10 Million % Songs Streamed 10Million Times  \
# 0            117         241                               97
# 1             59         166                               75
# 2             89         134                               95
# 3             69         143                               80
# 4             69         126                               70
# ..           ...         ...                              ...
# 995            0          29                               13
# 996            1          37                               59
# 997            4          11                                2
# 998            3           8                                7
# 999            2          23                                6
#
#     % Songs Streamed 100Million Times % Songs Streamed 1Billion Times
# 0                                  47                               2
# 1                                  27                               5
# 2                                  63                               2
# 3                                  39                               3
# 4                                  38                               3
# ..                                ...                             ...
# 995                                 0                               0
# 996                                 2                               0
# 997                                 1                               0
# 998                                 3                               0
# 999                                 1                               0
#
# [972 rows x 11 columns]

# %%
artist_df_cleaned.head()
# Out:
#    Position         Artist       Genre    Lead Streams  Tracks  1b  100m  10m  \
# 0         1          Drake     Hip-Hop  45,930,207,058     248   6   117  241
# 1         2     Ed Sheeran         Pop  35,009,165,977     222  10    59  166
# 2         3      Bad Bunny  Latin Trap  33,838,992,346     141   3    89  134
# 3         4     The Weeknd    R&B/Soul  30,759,273,612     178   6    69  143
# 4         5  Ariana Grande         Pop  30,199,885,343     181   5    69  126
#
#   % Songs Streamed 10Million Times % Songs Streamed 100Million Times  \
# 0                               97                                47
# 1                               75                                27
# 2                               95                                63
# 3                               80                                39
# 4                               70                                38
#
#   % Songs Streamed 1Billion Times
# 0                               2
# 1                               5
# 2                               2
# 3                               3
# 4                               3

# %%
artist_df_cleaned.dtypes
#artist_df_cleaned["% Songs Streamed 10Million Times"]astype.
# Out:
# Position                              int64
# Artist                               object
# Genre                                object
# Lead Streams                         object
# Tracks                                int32
# 1b                                    int64
# 100m                                  int64
# 10m                                   int64
# % Songs Streamed 10Million Times     object
# % Songs Streamed 100Million Times    object
# % Songs Streamed 1Billion Times      object
# dtype: object

# %%
artist_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 972 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Position                           972 non-null    int64
#  1   Artist                             972 non-null    object
#  2   Genre                              99 non-null     object
#  3   Lead Streams                       972 non-null    object
#  4   Tracks                             972 non-null    int32
#  5   1b                                 972 non-null    int64
#  6   100m                               972 non-null    int64
#  7   10m                                972 non-null    int64
#  8   % Songs Streamed 10Million Times   972 non-null    object
#  9   % Songs Streamed 100Million Times  972 non-null    object
#  10  % Songs Streamed 1Billion Times    972 non-null    object
# dtypes: int32(1), int64(4), object(6)
# memory usage: 87.3+ KB

# %%
artist_df_cleaned["% Songs Streamed 100Million Times"] = artist_df_cleaned['% Songs Streamed 100Million Times'].astype('int')
artist_df_cleaned.dtypes
# Out:
# Position                              int64
# Artist                               object
# Genre                                object
# Lead Streams                         object
# Tracks                                int32
# 1b                                    int64
# 100m                                  int64
# 10m                                   int64
# % Songs Streamed 10Million Times     object
# % Songs Streamed 100Million Times     int32
# % Songs Streamed 1Billion Times      object
# dtype: object

# %%
artist_df_cleaned["% Songs Streamed 10Million Times"] = artist_df_cleaned['% Songs Streamed 10Million Times'].astype('int')
artist_df_cleaned.dtypes
# Out:
# Position                              int64
# Artist                               object
# Genre                                object
# Lead Streams                         object
# Tracks                                int32
# 1b                                    int64
# 100m                                  int64
# 10m                                   int64
# % Songs Streamed 10Million Times      int32
# % Songs Streamed 100Million Times     int32
# % Songs Streamed 1Billion Times      object
# dtype: object

# %%
artist_df_cleaned["% Songs Streamed 1Billion Times"] = artist_df_cleaned['% Songs Streamed 1Billion Times'].astype('int')
artist_df_cleaned.dtypes
# Out:
# Position                              int64
# Artist                               object
# Genre                                object
# Lead Streams                         object
# Tracks                                int32
# 1b                                    int64
# 100m                                  int64
# 10m                                   int64
# % Songs Streamed 10Million Times      int32
# % Songs Streamed 100Million Times     int32
# % Songs Streamed 1Billion Times       int32
# dtype: object

# %% [markdown]
# # How many of them became popular?

# %% [markdown]
# # To find artist total tracks streamed 10 Million times greater than 70%

# %%
Streams_10M_df = pd.DataFrame(artist_df_cleaned.loc[artist_df_cleaned['% Songs Streamed 10Million Times']>80,:])
Streams_10M_df
# Out:
#      Position                Artist                  Genre    Lead Streams  \
# 0           1                 Drake                Hip-Hop  45,930,207,058
# 2           3             Bad Bunny             Latin Trap  33,838,992,346
# 12         13         Billie Eilish  Alternative/Indie pop  21,436,789,653
# 13         14            Juice WRLD                Hip-Hop  21,084,148,801
# 30         31        Kendrick Lamar                Hip-Hop  15,193,196,132
# 32         33         One Direction                    Pop  14,224,545,475
# 42         43                 Adele              Pop  Soul  12,995,508,731
# 46         47     Twenty One Pilots       Alternative Rock  12,230,092,784
# 48         49          Lil Uzi Vert                Hip-Hop  11,981,431,319
# 50         51                  Kygo       Electronic dance  11,824,039,530
# 66         67          Harry Styles                    Pop   9,137,076,671
# 85         86             Pop Smoke                Hip-Hop   8,114,250,149
# 91         92              Lil Peep                Emo Rap   7,807,725,799
# 94         95             Lil Nas X                    Pop   7,710,176,745
# 113       114                    NF                    NaN   7,063,003,125
# 115       116           Frank Ocean                    NaN   7,029,867,946
# 149       150      Marília Mendonça                    NaN   6,021,692,420
# 163       164                Polo G                    NaN   5,638,343,072
# 164       165         The Kid LAROI                    NaN   5,583,045,467
# 167       168                Camilo                    NaN   5,558,966,861
# 183       184            Luke Combs                    NaN   5,183,194,117
# 196       197      System Of A Down                    NaN   4,914,276,934
# 198       199                  Joji                    NaN   4,891,769,766
# 210       211                 Bazzi                    NaN   4,734,399,866
# 214       215          Paulo Londra                    NaN   4,648,248,854
# 216       217       Christian Nodal                    NaN   4,622,776,903
# 251       252         Morgan Wallen                    NaN   4,233,018,031
# 258       259                 Morat                    NaN   4,185,875,702
# 286       287            Ryan Lewis                    NaN   3,896,682,000
# 361       362         Daniel Caesar                    NaN   3,114,399,368
# 375       376         Alec Benjamin                    NaN   3,016,113,741
# 380       381              Måneskin                    NaN   2,990,300,974
# 398       399            Conan Gray                    NaN   2,879,943,163
# 419       420              Bon Iver                    NaN   2,770,728,013
# 438       439        Bradley Cooper                    NaN   2,666,104,022
# 468       469               Normani                    NaN   2,503,197,119
# 473       474                   PNL                    NaN   2,491,153,666
# 552       553                Clairo                    NaN   2,141,415,867
# 597       598              Ella Mai                    NaN   1,987,800,591
# 728       729  Cigarettes After Sex                    NaN   1,677,280,509
# 782       783                 Beret                    NaN   1,586,857,502
# 847       848                 Matuê                    NaN   1,446,021,815
# 865       866                Giveon                    NaN   1,423,652,277
# 953       954            Silk Sonic                    NaN   1,294,272,147
#
#      Tracks  1b  100m  10m  % Songs Streamed 10Million Times  \
# 0       248   6   117  241                                97
# 2       141   3    89  134                                95
# 12       62   4    41   57                                92
# 13      117   2    57  112                                96
# 30      103   1    32   91                                88
# 32      124   0    42  100                                81
# 42       70   3    24   59                                84
# 46       90   3    34   74                                82
# 48      129   1    30  117                                91
# 50      102   1    28   85                                83
# 66       27   3    24   25                                93
# 85       98   0    18   79                                81
# 91      101   0    21   87                                86
# 94       33   3    11   30                                91
# 113      81   1    16   81                               100
# 115      45   0    21   45                               100
# 149     117   0    22  105                                90
# 163      75   0    13   67                                89
# 164      47   1    15   42                                89
# 167      39   0    20   35                                90
# 183      56   0    15   55                                98
# 196      84   0     9   68                                81
# 198      50   0    14   41                                82
# 210      37   0    12   32                                86
# 214      30   0    13   29                                97
# 216      62   0    13   50                                81
# 251      58   0    11   58                               100
# 258      70   0    11   59                                84
# 286      33   1     6   28                                85
# 361      38   0     7   35                                92
# 375      34   1     7   31                                91
# 380      31   0     6   28                                90
# 398      26   0     6   26                               100
# 419      45   0     6   37                                82
# 438      12   1     4   10                                83
# 468      16   0     4   13                                81
# 473      72   0     2   66                                92
# 552      25   0     7   25                               100
# 597      39   0     6   34                                87
# 728      30   0     4   28                                93
# 782      48   0     3   40                                83
# 847      33   0     3   27                                82
# 865      18   0     3   18                               100
# 953      11   0     3   11                               100
#
#      % Songs Streamed 100Million Times  % Songs Streamed 1Billion Times
# 0                                   47                                2
# 2                                   63                                2
# 12                                  66                                6
# 13                                  49                                2
# 30                                  31                                1
# 32                                  34                                0
# 42                                  34                                4
# 46                                  38                                3
# 48                                  23                                1
# 50                                  27                                1
# 66                                  89                               11
# 85                                  18                                0
# 91                                  21                                0
# 94                                  33                                9
# 113                                 20                                1
# 115                                 47                                0
# 149                                 19                                0
# 163                                 17                                0
# 164                                 32                                2
# 167                                 51                                0
# 183                                 27                                0
# 196                                 11                                0
# 198                                 28                                0
# 210                                 32                                0
# 214                                 43                                0
# 216                                 21                                0
# 251                                 19                                0
# 258                                 16                                0
# 286                                 18                                3
# 361                                 18                                0
# 375                                 21                                3
# 380                                 19                                0
# 398                                 23                                0
# 419                                 13                                0
# 438                                 33                                8
# 468                                 25                                0
# 473                                  3                                0
# 552                                 28                                0
# 597                                 15                                0
# 728                                 13                                0
# 782                                  6                                0
# 847                                  9                                0
# 865                                 17                                0
# 953                                 27                                0

# %%
data_10M = Streams_10M_df[["Artist","% Songs Streamed 10Million Times"]]
data_10M
# Out:
#                    Artist  % Songs Streamed 10Million Times
# 0                   Drake                                97
# 2               Bad Bunny                                95
# 12          Billie Eilish                                92
# 13             Juice WRLD                                96
# 30         Kendrick Lamar                                88
# 32          One Direction                                81
# 42                  Adele                                84
# 46      Twenty One Pilots                                82
# 48           Lil Uzi Vert                                91
# 50                   Kygo                                83
# 66           Harry Styles                                93
# 85              Pop Smoke                                81
# 91               Lil Peep                                86
# 94              Lil Nas X                                91
# 113                    NF                               100
# 115           Frank Ocean                               100
# 149      Marília Mendonça                                90
# 163                Polo G                                89
# 164         The Kid LAROI                                89
# 167                Camilo                                90
# 183            Luke Combs                                98
# 196      System Of A Down                                81
# 198                  Joji                                82
# 210                 Bazzi                                86
# 214          Paulo Londra                                97
# 216       Christian Nodal                                81
# 251         Morgan Wallen                               100
# 258                 Morat                                84
# 286            Ryan Lewis                                85
# 361         Daniel Caesar                                92
# 375         Alec Benjamin                                91
# 380              Måneskin                                90
# 398            Conan Gray                               100
# 419              Bon Iver                                82
# 438        Bradley Cooper                                83
# 468               Normani                                81
# 473                   PNL                                92
# 552                Clairo                               100
# 597              Ella Mai                                87
# 728  Cigarettes After Sex                                93
# 782                 Beret                                83
# 847                 Matuê                                82
# 865                Giveon                               100
# 953            Silk Sonic                               100

# %%
Artist_names_10M = data_10M["Artist"].unique

# %%
                    #### THIS IS NOT WORKING CORRECTLY SHOULD BE ~ 40 ARTIST####

print(f"The total number of Artist achieving 80% or more of their tracks reaching 10 Million streams is: {len([[Artist_names_10M]])}")
# Out:
# The total number of Artist achieving 80% or more of their tracks reaching 10 Million streams is: 1

# %% [markdown]
# # Bar chart for percentages of popular songs

# %%
                                    #### ARTIST NAMES NOT WORKING ########

#creat list of Artist for x axis
Artist_names_10M = data_10M["Artist"].unique
x_axis = Streams_10M_df["Artist"]
streams = Streams_10M_df["% Songs Streamed 10Million Times"]
fig1, ax1 = plt.subplots(figsize=(10,14))

plt.bar(x_axis,streams, color='red', alpha=0.8, align='center')

plt.xticks( rotation='vertical')

plt.title("Artist passing 80% of songs in 10Million streams")
plt.xlabel("Artist")

plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(75, 101)
plt.ylabel("Strea2ms %")

#plt.savefig("../Desktop/")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, 'Strea2ms %')

# %%
Streams_100M_df = pd.DataFrame(artist_df_cleaned.loc[artist_df_cleaned['% Songs Streamed 100Million Times']>35,:])
Streams_100M
# Out:
#      Position             Artist                  Genre    Lead Streams  \
# 0           1              Drake                Hip-Hop  45,930,207,058
# 2           3          Bad Bunny             Latin Trap  33,838,992,346
# 3           4         The Weeknd               R&B/Soul  30,759,273,612
# 4           5      Ariana Grande                    Pop  30,199,885,343
# 8           9        Post Malone                Hip-Hop  27,472,535,195
# 12         13      Billie Eilish  Alternative/Indie pop  21,436,789,653
# 13         14         Juice WRLD                Hip-Hop  21,084,148,801
# 20         21       Travis Scott                Hip-Hop  19,184,512,661
# 25         26         Bruno Mars       Electronic dance  16,495,189,532
# 46         47  Twenty One Pilots       Alternative Rock  12,230,092,784
# 55         56     Camila Cabello              Pop Latin  10,718,386,609
# 66         67       Harry Styles                    Pop   9,137,076,671
# 115       116        Frank Ocean                    NaN   7,029,867,946
# 133       134                SZA                    NaN   6,412,432,497
# 167       168             Camilo                    NaN   5,558,966,861
# 214       215       Paulo Londra                    NaN   4,648,248,854
#
#      Tracks  1b  100m  10m  % Songs Streamed 10Million Times  \
# 0       248   6   117  241                                97
# 2       141   3    89  134                                95
# 3       178   6    69  143                                80
# 4       181   5    69  126                                70
# 8        82   8    54   65                                79
# 12       62   4    41   57                                92
# 13      117   2    57  112                                96
# 20      112   3    43   90                                80
# 25       79   5    31   61                                77
# 46       90   3    34   74                                82
# 55       60   2    23   43                                72
# 66       27   3    24   25                                93
# 115      45   0    21   45                               100
# 133      41   1    18   33                                80
# 167      39   0    20   35                                90
# 214      30   0    13   29                                97
#
#      % Songs Streamed 100Million Times  % Songs Streamed 1Billion Times
# 0                                   47                                2
# 2                                   63                                2
# 3                                   39                                3
# 4                                   38                                3
# 8                                   66                               10
# 12                                  66                                6
# 13                                  49                                2
# 20                                  38                                3
# 25                                  39                                6
# 46                                  38                                3
# 55                                  38                                3
# 66                                  89                               11
# 115                                 47                                0
# 133                                 44                                2
# 167                                 51                                0
# 214                                 43                                0

# %%
data_100M = Streams_100M_df[["Artist","% Songs Streamed 100Million Times"]]
data_100M
# Out:
#                 Artist  % Songs Streamed 100Million Times
# 0                Drake                                 47
# 2            Bad Bunny                                 63
# 3           The Weeknd                                 39
# 4        Ariana Grande                                 38
# 8          Post Malone                                 66
# 12       Billie Eilish                                 66
# 13          Juice WRLD                                 49
# 20        Travis Scott                                 38
# 25          Bruno Mars                                 39
# 46   Twenty One Pilots                                 38
# 55      Camila Cabello                                 38
# 66        Harry Styles                                 89
# 115        Frank Ocean                                 47
# 133                SZA                                 44
# 167             Camilo                                 51
# 214       Paulo Londra                                 43

# %%
data_100M["Artist"].unique
# Out:
# <bound method Series.unique of 0                  Drake
# 2              Bad Bunny
# 3             The Weeknd
# 4          Ariana Grande
# 8            Post Malone
# 12         Billie Eilish
# 13            Juice WRLD
# 20          Travis Scott
# 25            Bruno Mars
# 46     Twenty One Pilots
# 55        Camila Cabello
# 66          Harry Styles
# 115          Frank Ocean
# 133                  SZA
# 167               Camilo
# 214         Paulo Londra
# Name: Artist, dtype: object>

# %%
#created list of Artist for x axis using unique function

x_axis = Streams_100M_df["Artist"]
streams = Streams_100M_df["% Songs Streamed 100Million Times"]
fig1, ax1 = plt.subplots(figsize=(7, 12))


plt.bar(x_axis,streams, facecolor="m", alpha=0.8, align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ['Drake','Bad Bunny', 'The Weeknd', 'Ariana Grande', 'Post Malone', 'Billie Eilish', 'Juice WRLD', 'Travis Scott', 'Bruno Mars', 'Twenty One Pilots', 'Camila Cabello', 'Harry Styles', 'Frank Ocean', 'SZA', 'Camilo', 'Paulo Londra'],  rotation='vertical')

plt.xlim(-0.75,len(x_axis)-0.25)
plt.ylim(20, 94)
plt.title("Artist passing 35% of songs in 100Million streams")
plt.xlabel("Artist")
plt.ylabel("Streams %")
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0, 0.5, 'Streams %')

# %%
Streams_1B = pd.DataFrame(artist_df_cleaned.loc[artist_df_cleaned['% Songs Streamed 1Billion Times']>1,:])
Streams_1B
# Out:
#      Position         Artist       Genre    Lead Streams  Tracks  1b  100m  \
# 0           1          Drake     Hip-Hop  45,930,207,058     248   6   117
# 1           2     Ed Sheeran         Pop  35,009,165,977     222  10    59
# 2           3      Bad Bunny  Latin Trap  33,838,992,346     141   3    89
# 3           4     The Weeknd    R&B/Soul  30,759,273,612     178   6    69
# 4           5  Ariana Grande         Pop  30,199,885,343     181   5    69
# ..        ...            ...         ...             ...     ...  ..   ...
# 712       713         Dynoro         NaN   1,704,509,405      17   1     3
# 721       722  Trevor Daniel         NaN   1,684,760,342      48   1     2
# 748       749    beabadoobee         NaN   1,641,802,433      59   1     1
# 762       763          Powfu         NaN   1,617,907,608      66   1     1
# 926       927          Gotye         NaN   1,333,444,133      46   1     1
#
#      10m  % Songs Streamed 10Million Times  % Songs Streamed 100Million Times  \
# 0    241                                97                                 47
# 1    166                                75                                 27
# 2    134                                95                                 63
# 3    143                                80                                 39
# 4    126                                70                                 38
# ..   ...                               ...                                ...
# 712    9                                53                                 18
# 721   12                                25                                  4
# 748    9                                15                                  2
# 762   12                                18                                  2
# 926    9                                20                                  2
#
#      % Songs Streamed 1Billion Times
# 0                                  2
# 1                                  5
# 2                                  2
# 3                                  3
# 4                                  3
# ..                               ...
# 712                                6
# 721                                2
# 748                                2
# 762                                2
# 926                                2
#
# [65 rows x 11 columns]

# %%
Streams_1B_df = pd.DataFrame(artist_df_cleaned.loc[artist_df_cleaned['% Songs Streamed 1Billion Times']>2,:])
Streams_1B_df
# Out:
#      Position             Artist                  Genre    Lead Streams  \
# 1           2         Ed Sheeran                    Pop  35,009,165,977
# 3           4         The Weeknd               R&B/Soul  30,759,273,612
# 4           5      Ariana Grande                    Pop  30,199,885,343
# 5           6      Justin Bieber                    Pop  29,483,883,662
# 8           9        Post Malone                Hip-Hop  27,472,535,195
# 12         13      Billie Eilish  Alternative/Indie pop  21,436,789,653
# 15         16       XXXTENTACION                Hip-Hop  19,953,049,106
# 17         18             Khalid               R&B/Soul  19,690,052,960
# 18         19           Dua Lipa                    Pop  19,665,995,562
# 19         20    Imagine Dragons  Alternative/Indie pop  19,596,416,938
# 20         21       Travis Scott                Hip-Hop  19,184,512,661
# 23         24       Shawn Mendes                    Pop  17,706,595,827
# 25         26         Bruno Mars       Electronic dance  16,495,189,532
# 28         29          Sam Smith                    Pop  15,908,097,736
# 42         43              Adele              Pop  Soul  12,995,508,731
# 46         47  Twenty One Pilots       Alternative Rock  12,230,092,784
# 47         48         Marshmello       Electronic dance  12,078,260,875
# 55         56     Camila Cabello              Pop Latin  10,718,386,609
# 66         67       Harry Styles                    Pop   9,137,076,671
# 73         74       Charlie Puth                    Pop   8,485,914,369
# 74         75            Cardi B                Hip-Hop   8,477,939,050
# 94         95          Lil Nas X                    Pop   7,710,176,745
# 101       102               ZAYN                    NaN   7,511,901,161
# 107       108     Olivia Rodrigo                    NaN   7,340,845,148
# 131       132      Lewis Capaldi                    NaN   6,507,617,673
# 218       219   Hailee Steinfeld                    NaN   4,589,558,265
# 286       287         Ryan Lewis                    NaN   3,896,682,000
# 308       309        Tones And I                    NaN   3,697,594,279
# 338       339       benny blanco                    NaN   3,337,797,101
# 375       376      Alec Benjamin                    NaN   3,016,113,741
# 394       395         Dean Lewis                    NaN   2,903,655,994
# 438       439     Bradley Cooper                    NaN   2,666,104,022
# 514       515               DNCE                    NaN   2,280,705,753
# 619       620     Arizona Zervas                    NaN   1,932,876,803
# 712       713             Dynoro                    NaN   1,704,509,405
#
#      Tracks  1b  100m  10m  % Songs Streamed 10Million Times  \
# 1       222  10    59  166                                75
# 3       178   6    69  143                                80
# 4       181   5    69  126                                70
# 5       222   6    55  169                                76
# 8        82   8    54   65                                79
# 12       62   4    41   57                                92
# 15      131   7    42  104                                79
# 17      111   7    39   86                                77
# 18      193   6    33   80                                41
# 19      146   4    39  108                                74
# 20      112   3    43   90                                80
# 23      126   4    33   94                                75
# 25       79   5    31   61                                77
# 28      139   4    30   81                                58
# 42       70   3    24   59                                84
# 46       90   3    34   74                                82
# 47      143   4    17   83                                58
# 55       60   2    23   43                                72
# 66       27   3    24   25                                93
# 73      102   3    12   56                                55
# 74       67   2    18   51                                76
# 94       33   3    11   30                                91
# 101      85   3    15   67                                79
# 107      37   2    12   23                                62
# 131      48   2     9   28                                58
# 218      29   1    10   18                                62
# 286      33   1     6   28                                85
# 308      30   1     5   15                                50
# 338      20   1     6   12                                60
# 375      34   1     7   31                                91
# 394      40   1     6   25                                63
# 438      12   1     4   10                                83
# 514      32   1     4   18                                56
# 619      32   1     2   15                                47
# 712      17   1     3    9                                53
#
#      % Songs Streamed 100Million Times  % Songs Streamed 1Billion Times
# 1                                   27                                5
# 3                                   39                                3
# 4                                   38                                3
# 5                                   25                                3
# 8                                   66                               10
# 12                                  66                                6
# 15                                  32                                5
# 17                                  35                                6
# 18                                  17                                3
# 19                                  27                                3
# 20                                  38                                3
# 23                                  26                                3
# 25                                  39                                6
# 28                                  22                                3
# 42                                  34                                4
# 46                                  38                                3
# 47                                  12                                3
# 55                                  38                                3
# 66                                  89                               11
# 73                                  12                                3
# 74                                  27                                3
# 94                                  33                                9
# 101                                 18                                4
# 107                                 32                                5
# 131                                 19                                4
# 218                                 34                                3
# 286                                 18                                3
# 308                                 17                                3
# 338                                 30                                5
# 375                                 21                                3
# 394                                 15                                3
# 438                                 33                                8
# 514                                 13                                3
# 619                                  6                                3
# 712                                 18                                6

# %%
data_1B = Streams_1B_df[["Artist","% Songs Streamed 1Billion Times"]]
data_1B
# Out:
#                 Artist  % Songs Streamed 1Billion Times
# 1           Ed Sheeran                                5
# 3           The Weeknd                                3
# 4        Ariana Grande                                3
# 5        Justin Bieber                                3
# 8          Post Malone                               10
# 12       Billie Eilish                                6
# 15        XXXTENTACION                                5
# 17              Khalid                                6
# 18            Dua Lipa                                3
# 19     Imagine Dragons                                3
# 20        Travis Scott                                3
# 23        Shawn Mendes                                3
# 25          Bruno Mars                                6
# 28           Sam Smith                                3
# 42               Adele                                4
# 46   Twenty One Pilots                                3
# 47          Marshmello                                3
# 55      Camila Cabello                                3
# 66        Harry Styles                               11
# 73        Charlie Puth                                3
# 74             Cardi B                                3
# 94           Lil Nas X                                9
# 101               ZAYN                                4
# 107     Olivia Rodrigo                                5
# 131      Lewis Capaldi                                4
# 218   Hailee Steinfeld                                3
# 286         Ryan Lewis                                3
# 308        Tones And I                                3
# 338       benny blanco                                5
# 375      Alec Benjamin                                3
# 394         Dean Lewis                                3
# 438     Bradley Cooper                                8
# 514               DNCE                                3
# 619     Arizona Zervas                                3
# 712             Dynoro                                6

# %%
data_1B["Artist"].unique
# Out:
# <bound method Series.unique of 1             Ed Sheeran
# 3             The Weeknd
# 4          Ariana Grande
# 5          Justin Bieber
# 8            Post Malone
# 12         Billie Eilish
# 15          XXXTENTACION
# 17                Khalid
# 18              Dua Lipa
# 19       Imagine Dragons
# 20          Travis Scott
# 23          Shawn Mendes
# 25            Bruno Mars
# 28             Sam Smith
# 42                 Adele
# 46     Twenty One Pilots
# 47            Marshmello
# 55        Camila Cabello
# 66          Harry Styles
# 73          Charlie Puth
# 74               Cardi B
# 94             Lil Nas X
# 101                 ZAYN
# 107       Olivia Rodrigo
# 131        Lewis Capaldi
# 218     Hailee Steinfeld
# 286           Ryan Lewis
# 308          Tones And I
# 338         benny blanco
# 375        Alec Benjamin
# 394           Dean Lewis
# 438       Bradley Cooper
# 514                 DNCE
# 619       Arizona Zervas
# 712               Dynoro
# Name: Artist, dtype: object>

# %%
x_axis = Streams_1B_df["Artist"]
streams = Streams_1B_df["% Songs Streamed 1Billion Times"]
fig1, ax1 = plt.subplots(figsize=(10,14))


plt.bar(x_axis,streams, facecolor="b", alpha=0.8, align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ['Ed Sheeran', 'The Weeknd', 'Ariana Grande', 'Justin Bieber', 'Post Malone', 'Billie Eilish', 'XXXTENTACION', 'Khalid',
'Dua Lipa', 'Imagine Dragons', 'Travis Scott', 'Shawn Mendes', 'Bruno Mars', 'Sam Smith', 'Adele', 'Twenty One Pilots', 'Marshmello', 
'Camila Cabello', 'Harry Styles', 'Charlie Puth', 'Cardi B', 'Lil Nas X', 'ZAYN', 'Olivia Rodrigo', 'Lewis Capaldi', 'Hailee Steinfeld', 
'Ryan Lewis', 'Tones And I', 'Benny blanco', 'Alec Benjamin', 'Dean Lewis', 'Bradley Cooper', 'DNCE', 'Arizona Zervas', 'Dynoro'],  rotation='vertical')


plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, 12)
plt.title("Any Artist Streaming Over 1 Billion Times")
plt.xlabel("Artist")
plt.ylabel("Streams %")
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
# Text(0, 0.5, 'Streams %')

# %% [markdown]
# # Is there a difference with the top 10?

# %% [markdown]
# # What is the most popular genre?

# %% [markdown]
# # Pie chart for distribution of genres

# %% [markdown]
#    #                                           Codes not worked

# %%
                                    #### NOT WORKING ######
# How many artist songs reached 10 million streams, 100 million streams and 1 billion streams by 70%
Artists = artist_df_clean["artist"]
#passing_10_million = artist_df_cleaned["% Songs Streamed 10Million Times"=<70}"]

for Artist in artist_df_cleaned:
    ("% Songs Streamed 10Million Times") = <70:                                
    print(f"{artist} reaching 70% or greater for 10 Million streams

# %%
                                    ### NOT WORKING !!###
copy_df = artist_df_cleaned

#TRY MAKING BINS
bins = [70, 79, 89, 100]
#Create names for bins
group_names = ["A", "B", "C", "D"]

copy_df = pd.cut(copy_df["% Songs Streamed 10Million Times"], bins, labels=group_names, include_lowest=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9224/1742974109.py in <module>
#       7 group_names = ["A", "B", "C", "D"]
#       8
# ----> 9 copy_df = pd.cut(copy_df["% Songs Streamed 10Million Times"], bins, labels=group_names, include_lowest=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     285             raise ValueError("bins must increase monotonically.")
#     286
# --> 287     fac, bins = _bins_to_cuts(
#     288         x,
#     289         bins,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     444         else:
#     445             if len(labels) != len(bins) - 1:
# --> 446                 raise ValueError(
#     447                     "Bin labels must be one fewer than the number of bin edges"
#     448                 )
#
# ValueError: Bin labels must be one fewer than the number of bin edges
